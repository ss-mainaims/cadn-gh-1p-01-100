# %%
from ytmusicapi import YTMusic
import argparse
from pytube import YouTube
from pytube import Playlist
import threading
import time
import re

# %%
def time_logger(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        execution_time = end_time - start_time
        print(f"Function '{func.__name__}' took {execution_time:.4f} seconds to execute.")
        return result
    return wrapper
@time_logger
def get_artist_channel(artist:str)->list[dict]: 
    ytmusic = YTMusic()
    search = ytmusic.search(artist)
    global dat
    dat[artist.replace(' ','_')] = search
    print('Success loading search details data about',artist)
@time_logger
def download_batch(urls:list)->None:
    threads = []
    for url in urls:
        thread = threading.Thread(target=get_artist_channel, args=(url,))
        threads.append(thread)
        thread.start()
    for thread in threads:
        thread.join()
@time_logger
def batch_maker(urls:list)->list[str]:    
    batch_size = 4
    num_batches = len(urls) // batch_size
    batches = []
    for i in range(num_batches):
        batch = urls[i*batch_size : (i+1)*batch_size]
        batches.append(batch)
    return batches
@time_logger
def read_html_table(html_table:str)->list[str]:
  """Reads an HTML table and returns a tuple of the inner text of each tr element.

  Args:
    html_table: The HTML table as a string.

  Returns:
    A tuple of the inner text of each tr element, with each tr element separated
    by a space.
  """

  tr_elements = html_table.split("<tr>")
  tr_texts = []
  for tr_element in tr_elements:
    tr_texts.append(" ".join(tr_element.split("<td>")[1:-1]))
  return tuple(tr_texts)

def strip_tags(html_string):
    # Regular expression pattern to match HTML tags
    pattern = re.compile(r'<.*?>')
    
    # Remove HTML tags using the pattern
    stripped_string = re.sub(pattern, ' ', html_string)
    
    return stripped_string

# %%
dat  = {}

# %%
with open('untitled.txt') as f:
    text = f.read()

# %%
vals = read_html_table(text)
# Out:
# Function 'read_html_table' took 0.0105 seconds to execute.

# %%
vals[0:10]
# Out:
# ('',
#  '',
#  '1</td><td class="mp text"><div><a href="artist/taylorswift.html">Taylor Swift</a></div></td>',
#  '2</td><td class="mp text"><div><a href="artist/travisscott.html">Travis Scott</a></div></td>',
#  '3</td><td class="mp text"><div><a href="artist/theweeknd.html">The Weeknd</a></div></td>',
#  '4</td><td class="mp text"><div><a href="artist/karolg.html">KAROL G</a></div></td>',
#  '5</td><td class="mp text"><div><a href="artist/badbunny.html">Bad Bunny</a></div></td>',
#  '6</td><td class="mp text"><div><a href="artist/pesopluma.html">Peso Pluma</a></div></td>',
#  '7</td><td class="mp text"><div><a href="artist/dualipa.html">Dua Lipa</a></div></td>',
#  '8</td><td class="mp text"><div><a href="artist/feid.html">Feid</a></div></td>')

# %%
vals = [strip_tags(i).split() for i in vals if i!='']

# %%
artist = [" ".join(i[1:]) for i in vals]

# %%
artist[0:10]
# Out:
# ['Taylor Swift',
#  'Travis Scott',
#  'The Weeknd',
#  'KAROL G',
#  'Bad Bunny',
#  'Peso Pluma',
#  'Dua Lipa',
#  'Feid',
#  'NewJeans',
#  'Billie Eilish']

# %%
artist_batch = batch_maker(artist)
# Out:
# Function 'batch_maker' took 0.0011 seconds to execute.

# %%
artist_batch[0]
# Out:
# ['Taylor Swift', 'Travis Scott', 'The Weeknd', 'KAROL G']

# %%
for batch in artist_batch:
    download_batch(batch)
# Out:
# Success loading search details data about The Weeknd
# Function 'get_artist_channel' took 1.1342 seconds to execute.
# Success loading search details data about Travis Scott
# Function 'get_artist_channel' took 1.1700 seconds to execute.
# Success loading search details data about Taylor Swift
# Function 'get_artist_channel' took 1.1838 seconds to execute.
# Success loading search details data about KAROL G
# Function 'get_artist_channel' took 1.1889 seconds to execute.
# Function 'download_batch' took 1.1911 seconds to execute.
# Success loading search details data about Peso Pluma
# Function 'get_artist_channel' took 0.9683 seconds to execute.
# Success loading search details data about Bad Bunny
# Function 'get_artist_channel' took 1.0767 seconds to execute.
# Success loading search details data about Dua Lipa
# Function 'get_artist_channel' took 1.1155 seconds to execute.
# Success loading search details data about Feid
# Function 'get_artist_channel' took 1.2076 seconds to execute.
# Function 'download_batch' took 1.2106 seconds to execute.
# Success loading search details data about NewJeans
# Function 'get_artist_channel' took 0.9767 seconds to execute.
# Success loading search details data about Billie Eilish
# Function 'get_artist_channel' took 1.0629 seconds to execute.
# Success loading search details data about Olivia Rodrigo
# Function 'get_artist_channel' took 1.1194 seconds to execute.
# Success loading search details data about Drake
# Function 'get_artist_channel' took 1.4494 seconds to execute.
# Function 'download_batch' took 1.4532 seconds to execute.
# Success loading search details data about Miley Cyrus
# Function 'get_artist_channel' took 1.0517 seconds to execute.
# Success loading search details data about Post Malone
# Function 'get_artist_channel' took 1.0963 seconds to execute.
# Success loading search details data about Ed Sheeran
# Function 'get_artist_channel' took 1.1337 seconds to execute.
# Success loading search details data about Metro Boomin
# Function 'get_artist_channel' took 1.1790 seconds to execute.
# Function 'download_batch' took 1.1792 seconds to execute.
# Success loading search details data about Rema
# Function 'get_artist_channel' took 1.0488 seconds to execute.
# Success loading search details data about Myke Towers
# Function 'get_artist_channel' took 1.0729 seconds to execute.
# Success loading search details data about Lana Del Rey
# Function 'get_artist_channel' took 1.1058 seconds to execute.
# Success loading search details data about Jung Kook
# Function 'get_artist_channel' took 1.1098 seconds to execute.
# Function 'download_batch' took 1.1117 seconds to execute.
# Success loading search details data about Dave
# Function 'get_artist_channel' took 1.0002 seconds to execute.
# Success loading search details data about Grupo Frontera
# Function 'get_artist_channel' took 1.0020 seconds to execute.
# Success loading search details data about Harry Styles
# Function 'get_artist_channel' took 1.1689 seconds to execute.
# Success loading search details data about SZA
# Function 'get_artist_channel' took 1.2034 seconds to execute.
# Function 'download_batch' took 1.2053 seconds to execute.
# Success loading search details data about Imagine Dragons
# Function 'get_artist_channel' took 0.9922 seconds to execute.
# Success loading search details data about Doja Cat
# Function 'get_artist_channel' took 1.0034 seconds to execute.
# Success loading search details data about Gunna
# Function 'get_artist_channel' took 1.0540 seconds to execute.
# Success loading search details data about Ninho
# Function 'get_artist_channel' took 1.1068 seconds to execute.
# Function 'download_batch' took 1.1071 seconds to execute.
# Success loading search details data about Adele
# Function 'get_artist_channel' took 1.0333 seconds to execute.
# Success loading search details data about Quevedo
# Function 'get_artist_channel' took 1.0860 seconds to execute.
# Success loading search details data about Rauw Alejandro
# Function 'get_artist_channel' took 1.1195 seconds to execute.
# Success loading search details data about Calvin Harris
# Function 'get_artist_channel' took 1.1381 seconds to execute.
# Function 'download_batch' took 1.1414 seconds to execute.
# Success loading search details data about Asake
# Function 'get_artist_channel' took 0.8997 seconds to execute.
# Success loading search details data about Oliver Anthony Music
# Function 'get_artist_channel' took 1.0791 seconds to execute.
# Success loading search details data about Burna Boy
# Function 'get_artist_channel' took 1.1103 seconds to execute.
# Success loading search details data about Central Cee
# Function 'get_artist_channel' took 1.1123 seconds to execute.
# Function 'download_batch' took 1.1144 seconds to execute.
# Success loading search details data about Morgan Wallen
# Function 'get_artist_channel' took 1.0261 seconds to execute.
# Success loading search details data about Coldplay
# Function 'get_artist_channel' took 1.0297 seconds to execute.
# Success loading search details data about David Guetta
# Function 'get_artist_channel' took 1.0728 seconds to execute.
# Success loading search details data about Latto
# Function 'get_artist_channel' took 1.1169 seconds to execute.
# Function 'download_batch' took 1.1199 seconds to execute.
# Success loading search details data about Luke Combs
# Function 'get_artist_channel' took 1.0341 seconds to execute.
# Success loading search details data about Peggy Gou
# Function 'get_artist_channel' took 1.0424 seconds to execute.
# Success loading search details data about Beyoncé
# Function 'get_artist_channel' took 1.1534 seconds to execute.
# Success loading search details data about Nicki Minaj
# Function 'get_artist_channel' took 1.2288 seconds to execute.
# Function 'download_batch' took 1.2323 seconds to execute.
# Success loading search details data about Arijit Singh
# Function 'get_artist_channel' took 1.0040 seconds to execute.
# Success loading search details data about Jhayco
# Function 'get_artist_channel' took 1.0264 seconds to execute.
# Success loading search details data about Mora
# Function 'get_artist_channel' took 1.0581 seconds to execute.
# Success loading search details data about Kanye West
# Function 'get_artist_channel' took 1.1672 seconds to execute.
# Function 'download_batch' took 1.1696 seconds to execute.
# Success loading search details data about Carin Leon
# Function 'get_artist_channel' took 0.9625 seconds to execute.
# Success loading search details data about Eladio Carrión
# Function 'get_artist_channel' took 1.0051 seconds to execute.
# Success loading search details data about Hozier
# Function 'get_artist_channel' took 1.1380 seconds to execute.
# Success loading search details data about Manuel Turizo
# Function 'get_artist_channel' took 1.1552 seconds to execute.
# Function 'download_batch' took 1.1575 seconds to execute.
# Success loading search details data about Ayra Starr
# Function 'get_artist_channel' took 1.0099 seconds to execute.
# Success loading search details data about Ice Spice
# Function 'get_artist_channel' took 1.0796 seconds to execute.
# Success loading search details data about Quavo
# Function 'get_artist_channel' took 1.1232 seconds to execute.
# Success loading search details data about Young Miko
# Function 'get_artist_channel' took 1.1284 seconds to execute.
# Function 'download_batch' took 1.1318 seconds to execute.
# Success loading search details data about Anirudh Ravichander
# Function 'get_artist_channel' took 0.9117 seconds to execute.
# Success loading search details data about Tainy
# Function 'get_artist_channel' took 1.0629 seconds to execute.
# Success loading search details data about Bizarrap
# Function 'get_artist_channel' took 1.0902 seconds to execute.
# Success loading search details data about Tiësto
# Function 'get_artist_channel' took 1.1104 seconds to execute.
# Function 'download_batch' took 1.1108 seconds to execute.
# Success loading search details data about David Kushner
# Function 'get_artist_channel' took 0.9287 seconds to execute.
# Success loading search details data about Pritam
# Function 'get_artist_channel' took 1.0032 seconds to execute.
# Success loading search details data about Arctic Monkeys
# Function 'get_artist_channel' took 1.0636 seconds to execute.
# Success loading search details data about V
# Function 'get_artist_channel' took 1.0757 seconds to execute.
# Function 'download_batch' took 1.0784 seconds to execute.
# Success loading search details data about Aqua
# Function 'get_artist_channel' took 0.9651 seconds to execute.
# Success loading search details data about Bruno Mars
# Function 'get_artist_channel' took 1.0066 seconds to execute.
# Success loading search details data about 21 Savage
# Function 'get_artist_channel' took 1.0639 seconds to execute.
# Success loading search details data about Davido
# Function 'get_artist_channel' took 1.0690 seconds to execute.
# Function 'download_batch' took 1.0692 seconds to execute.
# Success loading search details data about Toto Cutugno
# Function 'get_artist_channel' took 1.0217 seconds to execute.
# Success loading search details data about 周杰伦
# Function 'get_artist_channel' took 1.0636 seconds to execute.
# Success loading search details data about Eminem
# Function 'get_artist_channel' took 1.1086 seconds to execute.
# Success loading search details data about Loreen
# Function 'get_artist_channel' took 1.1280 seconds to execute.
# Function 'download_batch' took 1.1316 seconds to execute.
# Success loading search details data about ROSALÍA
# Function 'get_artist_channel' took 1.0130 seconds to execute.
# Success loading search details data about Lewis Capaldi
# Function 'get_artist_channel' took 1.0422 seconds to execute.
# Success loading search details data about Anuel AA
# Function 'get_artist_channel' took 1.0638 seconds to execute.
# Success loading search details data about Lil Durk
# Function 'get_artist_channel' took 1.1491 seconds to execute.
# Function 'download_batch' took 1.1521 seconds to execute.
# Success loading search details data about Rihanna
# Function 'get_artist_channel' took 1.0014 seconds to execute.
# Success loading search details data about Junior H
# Function 'get_artist_channel' took 1.1182 seconds to execute.
# Success loading search details data about Byron Messia
# Function 'get_artist_channel' took 1.1387 seconds to execute.
# Success loading search details data about Justin Bieber
# Function 'get_artist_channel' took 1.1729 seconds to execute.
# Function 'download_batch' took 1.1734 seconds to execute.
# Success loading search details data about YOASOBI
# Function 'get_artist_channel' took 1.0237 seconds to execute.
# Success loading search details data about Maria Becerra
# Function 'get_artist_channel' took 1.0922 seconds to execute.
# Success loading search details data about BTS
# Function 'get_artist_channel' took 1.1370 seconds to execute.
# Success loading search details data about Shakira
# Function 'get_artist_channel' took 1.2579 seconds to execute.
# Function 'download_batch' took 1.2601 seconds to execute.
# Success loading search details data about BLACKPINK
# Function 'get_artist_channel' took 1.0853 seconds to execute.
# Success loading search details data about Fuerza Regida
# Function 'get_artist_channel' took 1.0892 seconds to execute.
# Success loading search details data about AP Dhillon
# Function 'get_artist_channel' took 1.1521 seconds to execute.
# Success loading search details data about Madonna
# Function 'get_artist_channel' took 1.3023 seconds to execute.
# Function 'download_batch' took 1.3121 seconds to execute.
# Success loading search details data about Future
# Function 'get_artist_channel' took 1.0862 seconds to execute.
# Success loading search details data about Gazo
# Function 'get_artist_channel' took 1.1032 seconds to execute.
# Success loading search details data about Ozuna
# Function 'get_artist_channel' took 1.2293 seconds to execute.
# Success loading search details data about Playboi Carti
# Function 'get_artist_channel' took 1.2491 seconds to execute.
# Function 'download_batch' took 1.2513 seconds to execute.
# Success loading search details data about Karan Aujla
# Function 'get_artist_channel' took 1.0123 seconds to execute.
# Success loading search details data about Jain
# Function 'get_artist_channel' took 1.0732 seconds to execute.
# Success loading search details data about OneRepublic
# Function 'get_artist_channel' took 1.0879 seconds to execute.
# Success loading search details data about Ariana Grande
# Function 'get_artist_channel' took 1.1421 seconds to execute.
# Function 'download_batch' took 1.1426 seconds to execute.
# Success loading search details data about Zach Bryan
# Function 'get_artist_channel' took 0.9298 seconds to execute.
# Success loading search details data about Ke Personajes
# Function 'get_artist_channel' took 0.9787 seconds to execute.
# Success loading search details data about Semicenk
# Function 'get_artist_channel' took 1.1661 seconds to execute.
# Success loading search details data about Chris Brown
# Function 'get_artist_channel' took 1.1890 seconds to execute.
# Function 'download_batch' took 1.1907 seconds to execute.
# Success loading search details data about Omah Lay
# Function 'get_artist_channel' took 1.0276 seconds to execute.
# Success loading search details data about Valiant
# Function 'get_artist_channel' took 1.0518 seconds to execute.
# Success loading search details data about J. Cole
# Function 'get_artist_channel' took 1.1607 seconds to execute.
# Success loading search details data about Sam Smith
# Function 'get_artist_channel' took 1.2094 seconds to execute.
# Function 'download_batch' took 1.2120 seconds to execute.
# Success loading search details data about Natanael Cano
# Function 'get_artist_channel' took 1.0298 seconds to execute.
# Success loading search details data about One Direction
# Function 'get_artist_channel' took 1.0585 seconds to execute.
# Success loading search details data about Mrs. Green Apple
# Function 'get_artist_channel' took 1.1229 seconds to execute.
# Success loading search details data about JUL
# Function 'get_artist_channel' took 1.1559 seconds to execute.
# Function 'download_batch' took 1.1570 seconds to execute.
# Success loading search details data about aespa
# Function 'get_artist_channel' took 0.9706 seconds to execute.
# Success loading search details data about Ikky
# Function 'get_artist_channel' took 1.0000 seconds to execute.
# Success loading search details data about Frank Ocean
# Function 'get_artist_channel' took 1.1090 seconds to execute.
# Success loading search details data about P!nk
# Function 'get_artist_channel' took 1.2288 seconds to execute.
# Function 'download_batch' took 1.2292 seconds to execute.
# Success loading search details data about Yng Lvcas
# Function 'get_artist_channel' took 1.0707 seconds to execute.
# Success loading search details data about Tom Odell
# Function 'get_artist_channel' took 1.1113 seconds to execute.
# Success loading search details data about Lady Gaga
# Function 'get_artist_channel' took 1.3209 seconds to execute.
# Success loading search details data about Big One
# Function 'get_artist_channel' took 1.4508 seconds to execute.
# Function 'download_batch' took 1.4521 seconds to execute.
# Success loading search details data about Fleetwood Mac
# Function 'get_artist_channel' took 1.0356 seconds to execute.
# Success loading search details data about Jimin
# Function 'get_artist_channel' took 1.0605 seconds to execute.
# Success loading search details data about Apache 207
# Function 'get_artist_channel' took 1.1610 seconds to execute.
# Success loading search details data about RAYE
# Function 'get_artist_channel' took 1.1816 seconds to execute.
# Function 'download_batch' took 1.1821 seconds to execute.
# Success loading search details data about SEVENTEEN
# Function 'get_artist_channel' took 0.9521 seconds to execute.
# Success loading search details data about Grupo Firme
# Function 'get_artist_channel' took 1.0348 seconds to execute.
# Success loading search details data about Kendrick Lamar
# Function 'get_artist_channel' took 1.0947 seconds to execute.
# Success loading search details data about Selena Gomez
# Function 'get_artist_channel' took 1.3738 seconds to execute.
# Function 'download_batch' took 1.3742 seconds to execute.
# Success loading search details data about Libianca
# Function 'get_artist_channel' took 0.9885 seconds to execute.
# Success loading search details data about Shubh
# Function 'get_artist_channel' took 1.0089 seconds to execute.
# Success loading search details data about Anne-Marie
# Function 'get_artist_channel' took 1.0799 seconds to execute.
# Success loading search details data about Amitabh Bhattacharya
# Function 'get_artist_channel' took 1.1362 seconds to execute.
# Function 'download_batch' took 1.1374 seconds to execute.
# Success loading search details data about SDM
# Function 'get_artist_channel' took 1.0109 seconds to execute.
# Success loading search details data about Shreya Ghoshal
# Function 'get_artist_channel' took 1.0297 seconds to execute.
# Success loading search details data about ANNA ASTI
# Function 'get_artist_channel' took 1.1060 seconds to execute.
# Success loading search details data about Bebe Rexha
# Function 'get_artist_channel' took 1.3275 seconds to execute.
# Function 'download_batch' took 1.3300 seconds to execute.
# Success loading search details data about Morad
# Function 'get_artist_channel' took 0.9356 seconds to execute.
# Success loading search details data about Bad Gyal
# Function 'get_artist_channel' took 1.1120 seconds to execute.
# Success loading search details data about Olamide
# Function 'get_artist_channel' took 1.1269 seconds to execute.
# Success loading search details data about (G)I-DLE
# Function 'get_artist_channel' took 1.1282 seconds to execute.
# Function 'download_batch' took 1.1284 seconds to execute.
# Success loading search details data about Yandel
# Function 'get_artist_channel' took 1.0273 seconds to execute.
# Success loading search details data about Charlie Puth
# Function 'get_artist_channel' took 1.0749 seconds to execute.
# Success loading search details data about Luis Miguel
# Function 'get_artist_channel' took 1.0784 seconds to execute.
# Success loading search details data about Soolking
# Function 'get_artist_channel' took 1.1333 seconds to execute.
# Function 'download_batch' took 1.1338 seconds to execute.
# Success loading search details data about j-hope
# Function 'get_artist_channel' took 1.0349 seconds to execute.
# Success loading search details data about Sfera Ebbasta
# Function 'get_artist_channel' took 1.0517 seconds to execute.
# Success loading search details data about Eslabon Armado
# Function 'get_artist_channel' took 1.0903 seconds to execute.
# Success loading search details data about MACAN
# Function 'get_artist_channel' took 1.0965 seconds to execute.
# Function 'download_batch' took 1.0976 seconds to execute.
# Success loading search details data about LINKIN PARK
# Function 'get_artist_channel' took 1.0007 seconds to execute.
# Success loading search details data about Jere Klein
# Function 'get_artist_channel' took 1.0488 seconds to execute.
# Success loading search details data about Duki
# Function 'get_artist_channel' took 1.0768 seconds to execute.
# Success loading search details data about Emilia
# Function 'get_artist_channel' took 1.0932 seconds to execute.
# Function 'download_batch' took 1.1047 seconds to execute.
# Success loading search details data about Tiakola
# Function 'get_artist_channel' took 0.9737 seconds to execute.
# Success loading search details data about Elton John
# Function 'get_artist_channel' took 1.0204 seconds to execute.
# Success loading search details data about Purple Disco Machine
# Function 'get_artist_channel' took 1.0860 seconds to execute.
# Success loading search details data about Daft Punk
# Function 'get_artist_channel' took 1.2445 seconds to execute.
# Function 'download_batch' took 1.2447 seconds to execute.
# Success loading search details data about Ryan Castro
# Function 'get_artist_channel' took 1.0714 seconds to execute.
# Success loading search details data about Nicki Nicole
# Function 'get_artist_channel' took 1.0885 seconds to execute.
# Success loading search details data about Lil Baby
# Function 'get_artist_channel' took 1.1322 seconds to execute.
# Success loading search details data about J Hus
# Function 'get_artist_channel' took 1.2125 seconds to execute.
# Function 'download_batch' took 1.2146 seconds to execute.
# Success loading search details data about Ski Aggu
# Function 'get_artist_channel' took 1.0132 seconds to execute.
# Success loading search details data about cassö
# Function 'get_artist_channel' took 1.0498 seconds to execute.
# Success loading search details data about Jelena Karleusa
# Function 'get_artist_channel' took 1.0679 seconds to execute.
# Success loading search details data about Lost Frequencies
# Function 'get_artist_channel' took 1.1343 seconds to execute.
# Function 'download_batch' took 1.1366 seconds to execute.
# Success loading search details data about The Kolors
# Function 'get_artist_channel' took 1.0272 seconds to execute.
# Success loading search details data about Romeo Santos
# Function 'get_artist_channel' took 1.0827 seconds to execute.
# Success loading search details data about Mabel Matiz
# Function 'get_artist_channel' took 1.1064 seconds to execute.
# Success loading search details data about Geolier
# Function 'get_artist_channel' took 1.1267 seconds to execute.
# Function 'download_batch' took 1.1289 seconds to execute.
# Success loading search details data about JIHYO
# Function 'get_artist_channel' took 0.9459 seconds to execute.
# Success loading search details data about Marshmello
# Function 'get_artist_channel' took 1.0275 seconds to execute.
# Success loading search details data about LE SSERAFIM
# Function 'get_artist_channel' took 1.0570 seconds to execute.
# Success loading search details data about Sia
# Function 'get_artist_channel' took 1.2076 seconds to execute.
# Function 'download_batch' took 1.2080 seconds to execute.
# Success loading search details data about BM
# Function 'get_artist_channel' took 1.0117 seconds to execute.
# Success loading search details data about Morat
# Function 'get_artist_channel' took 1.0171 seconds to execute.
# Success loading search details data about Werenoi
# Function 'get_artist_channel' took 1.0363 seconds to execute.
# Success loading search details data about Saiko
# Function 'get_artist_channel' took 1.1019 seconds to execute.
# Function 'download_batch' took 1.1031 seconds to execute.
# Success loading search details data about Måneskin
# Function 'get_artist_channel' took 0.9402 seconds to execute.
# Success loading search details data about Kali Uchis
# Function 'get_artist_channel' took 0.9855 seconds to execute.
# Success loading search details data about 周杰倫
# Function 'get_artist_channel' took 1.0037 seconds to execute.
# Success loading search details data about Diamond Platnumz
# Function 'get_artist_channel' took 1.0748 seconds to execute.
# Function 'download_batch' took 1.0762 seconds to execute.
# Success loading search details data about FIFTY FIFTY
# Function 'get_artist_channel' took 1.0609 seconds to execute.
# Success loading search details data about LIT killah
# Function 'get_artist_channel' took 1.0730 seconds to execute.
# Success loading search details data about DYSTINCT
# Function 'get_artist_channel' took 1.0764 seconds to execute.
# Success loading search details data about Russ
# Function 'get_artist_channel' took 1.1101 seconds to execute.
# Function 'download_batch' took 1.1131 seconds to execute.
# Success loading search details data about James Arthur
# Function 'get_artist_channel' took 1.0076 seconds to execute.
# Success loading search details data about Addison Rae
# Function 'get_artist_channel' took 1.0332 seconds to execute.
# Success loading search details data about Miyagi
# Function 'get_artist_channel' took 1.1177 seconds to execute.
# Success loading search details data about D-Block Europe
# Function 'get_artist_channel' took 1.1374 seconds to execute.
# Function 'download_batch' took 1.1398 seconds to execute.
# Success loading search details data about Arcángel
# Function 'get_artist_channel' took 0.9985 seconds to execute.
# Success loading search details data about IVE
# Function 'get_artist_channel' took 1.0171 seconds to execute.
# Success loading search details data about Azahriah
# Function 'get_artist_channel' took 1.0415 seconds to execute.
# Success loading search details data about Don Omar
# Function 'get_artist_channel' took 1.0974 seconds to execute.
# Function 'download_batch' took 1.1005 seconds to execute.
# Success loading search details data about Lazza
# Function 'get_artist_channel' took 1.0182 seconds to execute.
# Success loading search details data about DJ Maphorisa
# Function 'get_artist_channel' took 1.0436 seconds to execute.
# Success loading search details data about Ciara
# Function 'get_artist_channel' took 1.0812 seconds to execute.
# Success loading search details data about Brray
# Function 'get_artist_channel' took 1.1547 seconds to execute.
# Function 'download_batch' took 1.1568 seconds to execute.
# Success loading search details data about Yahritza Y Su Esencia
# Function 'get_artist_channel' took 0.9876 seconds to execute.
# Success loading search details data about Rod Wave
# Function 'get_artist_channel' took 1.0767 seconds to execute.
# Success loading search details data about Jay Wheeler
# Function 'get_artist_channel' took 1.1235 seconds to execute.
# Success loading search details data about Damso
# Function 'get_artist_channel' took 1.2133 seconds to execute.
# Function 'download_batch' took 1.2140 seconds to execute.
# Success loading search details data about A.V.G
# Function 'get_artist_channel' took 1.0282 seconds to execute.
# Success loading search details data about Veigh
# Function 'get_artist_channel' took 1.0950 seconds to execute.
# Success loading search details data about Stray Kids
# Function 'get_artist_channel' took 1.1340 seconds to execute.
# Success loading search details data about MC Kevin o Chris
# Function 'get_artist_channel' took 1.3051 seconds to execute.
# Function 'download_batch' took 1.3075 seconds to execute.
# Success loading search details data about Bibi Babydoll
# Function 'get_artist_channel' took 0.9646 seconds to execute.
# Success loading search details data about Ludwig Göransson
# Function 'get_artist_channel' took 1.0561 seconds to execute.
# Success loading search details data about AYLIVA
# Function 'get_artist_channel' took 1.0810 seconds to execute.
# Success loading search details data about Tedua
# Function 'get_artist_channel' took 1.2395 seconds to execute.
# Function 'download_batch' took 1.2425 seconds to execute.
# Success loading search details data about Maluma
# Function 'get_artist_channel' took 1.0171 seconds to execute.
# Success loading search details data about Rels B
# Function 'get_artist_channel' took 1.0500 seconds to execute.
# Success loading search details data about Troye Sivan
# Function 'get_artist_channel' took 1.0731 seconds to execute.
# Success loading search details data about Ana Castela
# Function 'get_artist_channel' took 1.0961 seconds to execute.
# Function 'download_batch' took 1.0982 seconds to execute.
# Success loading search details data about Fally Ipupa
# Function 'get_artist_channel' took 1.0368 seconds to execute.
# Success loading search details data about Shilpa Rao
# Function 'get_artist_channel' took 1.1765 seconds to execute.
# Success loading search details data about Heuss L'enfoiré
# Function 'get_artist_channel' took 1.1884 seconds to execute.
# Exception in thread Thread-215 (wrapper):
# Traceback (most recent call last):
#   File "/usr/local/python/3.10.8/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/local/python/3.10.8/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_27366/2002304524.py", line 4, in wrapper
#   File "/tmp/ipykernel_27366/2002304524.py", line 13, in get_artist_channel
#   File "/usr/local/python/3.10.8/lib/python3.10/site-packages/ytmusicapi/mixins/search.py", line 218, in search
#     parse_search_results(results, search_result_types, type, category))
#   File "/usr/local/python/3.10.8/lib/python3.10/site-packages/ytmusicapi/parsers/search.py", line 142, in parse_search_results
#     return [
#   File "/usr/local/python/3.10.8/lib/python3.10/site-packages/ytmusicapi/parsers/search.py", line 143, in <listcomp>
#     parse_search_result(result[MRLIR], search_result_types, resultType, category)
#   File "/usr/local/python/3.10.8/lib/python3.10/site-packages/ytmusicapi/parsers/search.py", line 80, in parse_search_result
#     search_result['name'] = get_item_text(data, 1, 2)
#   File "/usr/local/python/3.10.8/lib/python3.10/site-packages/ytmusicapi/parsers/_utils.py", line 30, in get_item_text
#     return column['text']['runs'][run_index]['text']
# IndexError: list index out of range
# Function 'download_batch' took 1.5162 seconds to execute.
# Success loading search details data about Mahalini
# Function 'get_artist_channel' took 1.0487 seconds to execute.
# Success loading search details data about The Kid LAROI
# Function 'get_artist_channel' took 1.0723 seconds to execute.
# Success loading search details data about Tiago PZK
# Function 'get_artist_channel' took 1.0786 seconds to execute.
# Success loading search details data about Coi Leray
# Function 'get_artist_channel' took 1.1733 seconds to execute.
# Function 'download_batch' took 1.1736 seconds to execute.
# Success loading search details data about Cris Mj
# Function 'get_artist_channel' took 1.0360 seconds to execute.
# Success loading search details data about Sachin-Jigar
# Function 'get_artist_channel' took 1.0616 seconds to execute.
# Success loading search details data about Ahmed Saad
# Function 'get_artist_channel' took 1.0666 seconds to execute.
# Success loading search details data about TINI
# Function 'get_artist_channel' took 1.0816 seconds to execute.
# Function 'download_batch' took 1.0818 seconds to execute.
# Success loading search details data about Glass Animals
# Function 'get_artist_channel' took 1.0812 seconds to execute.
# Success loading search details data about Guilherme
# Function 'get_artist_channel' took 1.0838 seconds to execute.
# Success loading search details data about Smolasty
# Function 'get_artist_channel' took 1.1462 seconds to execute.
# Success loading search details data about Tyler ICU
# Function 'get_artist_channel' took 1.3318 seconds to execute.
# Function 'download_batch' took 1.3320 seconds to execute.
# Success loading search details data about Sabrina Carpenter
# Function 'get_artist_channel' took 1.0690 seconds to execute.
# Success loading search details data about RAF Camora
# Function 'get_artist_channel' took 1.2100 seconds to execute.
# Success loading search details data about Young Thug
# Function 'get_artist_channel' took 1.2136 seconds to execute.
# Success loading search details data about Kabza De Small
# Function 'get_artist_channel' took 1.2194 seconds to execute.
# Function 'download_batch' took 1.2216 seconds to execute.
# Success loading search details data about Tory Lanez
# Function 'get_artist_channel' took 1.0656 seconds to execute.
# Success loading search details data about FMK
# Function 'get_artist_channel' took 1.1119 seconds to execute.
# Success loading search details data about Devito
# Function 'get_artist_channel' took 1.1120 seconds to execute.
# Success loading search details data about Charli XCX
# Function 'get_artist_channel' took 1.1275 seconds to execute.
# Function 'download_batch' took 1.1279 seconds to execute.
# Success loading search details data about MC 張天賦
# Function 'get_artist_channel' took 1.0186 seconds to execute.
# Success loading search details data about Pinguini Tattici Nucleari
# Function 'get_artist_channel' took 1.0675 seconds to execute.
# Success loading search details data about A.R. Rahman
# Function 'get_artist_channel' took 1.0699 seconds to execute.
# Success loading search details data about The Neighbourhood
# Function 'get_artist_channel' took 1.0744 seconds to execute.
# Function 'download_batch' took 1.0761 seconds to execute.
# Success loading search details data about Noah Kahan
# Function 'get_artist_channel' took 1.0038 seconds to execute.
# Success loading search details data about Cristiano
# Function 'get_artist_channel' took 1.0490 seconds to execute.
# Success loading search details data about Aya Nakamura
# Function 'get_artist_channel' took 1.1650 seconds to execute.
# Success loading search details data about Zé Neto
# Function 'get_artist_channel' took 1.1896 seconds to execute.
# Function 'download_batch' took 1.1909 seconds to execute.
# Success loading search details data about Plan B
# Function 'get_artist_channel' took 1.0812 seconds to execute.
# Success loading search details data about Baby Lullaby Academy
# Function 'get_artist_channel' took 1.1686 seconds to execute.
# Success loading search details data about Chris Stapleton
# Function 'get_artist_channel' took 1.2080 seconds to execute.
# Success loading search details data about Daddy Yankee
# Function 'get_artist_channel' took 1.2928 seconds to execute.
# Function 'download_batch' took 1.2963 seconds to execute.
# Success loading search details data about Shiva
# Function 'get_artist_channel' took 1.0033 seconds to execute.
# Success loading search details data about Michael Jackson
# Function 'get_artist_channel' took 1.0973 seconds to execute.
# Success loading search details data about Jungle
# Function 'get_artist_channel' took 1.1033 seconds to execute.
# Success loading search details data about Lil Uzi Vert
# Function 'get_artist_channel' took 1.1372 seconds to execute.
# Function 'download_batch' took 1.1373 seconds to execute.
# Success loading search details data about Motive
# Function 'get_artist_channel' took 1.0100 seconds to execute.
# Success loading search details data about Jão
# Function 'get_artist_channel' took 1.0712 seconds to execute.
# Success loading search details data about Lin-Manuel Miranda
# Function 'get_artist_channel' took 1.0893 seconds to execute.
# Success loading search details data about Pop Smoke
# Function 'get_artist_channel' took 1.3378 seconds to execute.
# Function 'download_batch' took 1.3381 seconds to execute.
# Success loading search details data about Jasleen Royal
# Function 'get_artist_channel' took 0.9987 seconds to execute.
# Success loading search details data about DENNIS
# Function 'get_artist_channel' took 1.0060 seconds to execute.
# Success loading search details data about Calum Scott
# Function 'get_artist_channel' took 1.0636 seconds to execute.
# Success loading search details data about J Balvin
# Function 'get_artist_channel' took 1.1080 seconds to execute.
# Function 'download_batch' took 1.1092 seconds to execute.
# Success loading search details data about PHARAOH
# Function 'get_artist_channel' took 0.9975 seconds to execute.
# Success loading search details data about Daniel Caesar
# Function 'get_artist_channel' took 1.0264 seconds to execute.
# Success loading search details data about Lauv
# Function 'get_artist_channel' took 1.1119 seconds to execute.
# Success loading search details data about Sebastian Yatra
# Function 'get_artist_channel' took 1.1545 seconds to execute.
# Function 'download_batch' took 1.1581 seconds to execute.
# Success loading search details data about Agust D
# Function 'get_artist_channel' took 0.9730 seconds to execute.
# Success loading search details data about Naps
# Function 'get_artist_channel' took 1.0055 seconds to execute.
# Success loading search details data about BLOK3
# Function 'get_artist_channel' took 1.0394 seconds to execute.
# Success loading search details data about Ellie Goulding
# Function 'get_artist_channel' took 1.0782 seconds to execute.
# Function 'download_batch' took 1.0805 seconds to execute.
# Success loading search details data about Jala Brat
# Function 'get_artist_channel' took 1.0356 seconds to execute.
# Success loading search details data about Hov1
# Function 'get_artist_channel' took 1.0532 seconds to execute.
# Success loading search details data about Drillionaire
# Function 'get_artist_channel' took 1.1007 seconds to execute.
# Success loading search details data about UZI
# Function 'get_artist_channel' took 1.2422 seconds to execute.
# Function 'download_batch' took 1.2442 seconds to execute.
# Success loading search details data about Rammstein
# Function 'get_artist_channel' took 0.9724 seconds to execute.
# Success loading search details data about Maroon 5
# Function 'get_artist_channel' took 1.1161 seconds to execute.
# Success loading search details data about Felipe Amorim
# Function 'get_artist_channel' took 1.1223 seconds to execute.
# Success loading search details data about Tulus
# Function 'get_artist_channel' took 1.1242 seconds to execute.
# Function 'download_batch' took 1.1263 seconds to execute.
# Success loading search details data about Bailey Zimmerman
# Function 'get_artist_channel' took 1.0260 seconds to execute.
# Success loading search details data about Gabito Ballesteros
# Function 'get_artist_channel' took 1.1140 seconds to execute.
# Success loading search details data about Victony
# Function 'get_artist_channel' took 1.1231 seconds to execute.
# Success loading search details data about sanah
# Function 'get_artist_channel' took 1.1325 seconds to execute.
# Function 'download_batch' took 1.1349 seconds to execute.
# Success loading search details data about Kungs
# Function 'get_artist_channel' took 1.0412 seconds to execute.
# Success loading search details data about JVKE
# Function 'get_artist_channel' took 1.0872 seconds to execute.
# Success loading search details data about Mithoon
# Function 'get_artist_channel' took 1.1058 seconds to execute.
# Success loading search details data about Malie Donn
# Function 'get_artist_channel' took 1.1547 seconds to execute.
# Function 'download_batch' took 1.1549 seconds to execute.
# Success loading search details data about Alfredo Olivas
# Function 'get_artist_channel' took 1.0125 seconds to execute.
# Success loading search details data about DESH
# Function 'get_artist_channel' took 1.0303 seconds to execute.
# Success loading search details data about VAUNDY
# Function 'get_artist_channel' took 1.0666 seconds to execute.
# Success loading search details data about back number
# Function 'get_artist_channel' took 1.2163 seconds to execute.
# Function 'download_batch' took 1.2165 seconds to execute.
# Success loading search details data about 群星
# Function 'get_artist_channel' took 0.9814 seconds to execute.
# Success loading search details data about Three Man Down
# Function 'get_artist_channel' took 1.0137 seconds to execute.
# Success loading search details data about Vulgo FK
# Function 'get_artist_channel' took 1.1445 seconds to execute.
# Success loading search details data about Rylo Rodriguez
# Function 'get_artist_channel' took 1.1789 seconds to execute.
# Function 'download_batch' took 1.1806 seconds to execute.
# Success loading search details data about Nadin Amizah
# Function 'get_artist_channel' took 0.9568 seconds to execute.
# Success loading search details data about Bnxn
# Function 'get_artist_channel' took 1.0358 seconds to execute.
# Success loading search details data about Tears for Fears
# Function 'get_artist_channel' took 1.0679 seconds to execute.
# Success loading search details data about Katy Perry
# Function 'get_artist_channel' took 1.0971 seconds to execute.
# Function 'download_batch' took 1.0989 seconds to execute.
# Success loading search details data about Sezen Aksu
# Function 'get_artist_channel' took 1.1015 seconds to execute.
# Success loading search details data about Henrique &amp; Juliano
# Function 'get_artist_channel' took 1.1289 seconds to execute.
# Success loading search details data about Sebastián Yatra
# Function 'get_artist_channel' took 1.1495 seconds to execute.
# Success loading search details data about Jay Chou
# Function 'get_artist_channel' took 1.1913 seconds to execute.
# Function 'download_batch' took 1.1918 seconds to execute.
# Success loading search details data about Super Subu
# Function 'get_artist_channel' took 0.9407 seconds to execute.
# Success loading search details data about Cigarettes After Sex
# Function 'get_artist_channel' took 0.9810 seconds to execute.
# Success loading search details data about Alan Walker
# Function 'get_artist_channel' took 1.1590 seconds to execute.
# Success loading search details data about TREASURE
# Function 'get_artist_channel' took 1.1793 seconds to execute.
# Function 'download_batch' took 1.1816 seconds to execute.
# Success loading search details data about Becky G
# Function 'get_artist_channel' took 1.0184 seconds to execute.
# Success loading search details data about Kenshi Yonezu
# Function 'get_artist_channel' took 1.0679 seconds to execute.
# Success loading search details data about Ella Henderson
# Function 'get_artist_channel' took 1.1916 seconds to execute.
# Success loading search details data about El Jordan 23
# Function 'get_artist_channel' took 1.2581 seconds to execute.
# Function 'download_batch' took 1.2584 seconds to execute.
# Success loading search details data about OFFICIAL HIGE DANDISM
# Function 'get_artist_channel' took 0.9946 seconds to execute.
# Success loading search details data about Calin
# Function 'get_artist_channel' took 1.0253 seconds to execute.
# Success loading search details data about Dj Brunin XM
# Function 'get_artist_channel' took 1.0534 seconds to execute.
# Success loading search details data about Juice WRLD
# Function 'get_artist_channel' took 1.1985 seconds to execute.
# Function 'download_batch' took 1.1994 seconds to execute.
# Success loading search details data about Darshan Raval
# Function 'get_artist_channel' took 0.9690 seconds to execute.
# Success loading search details data about Ruger
# Function 'get_artist_channel' took 0.9980 seconds to execute.
# Success loading search details data about iKON
# Function 'get_artist_channel' took 1.0332 seconds to execute.
# Success loading search details data about Pitbull
# Function 'get_artist_channel' took 1.0879 seconds to execute.
# Function 'download_batch' took 1.0903 seconds to execute.
# Success loading search details data about STAYC
# Function 'get_artist_channel' took 0.9633 seconds to execute.
# Success loading search details data about Jazzy
# Function 'get_artist_channel' took 0.9679 seconds to execute.
# Success loading search details data about Macklemore
# Function 'get_artist_channel' took 1.0789 seconds to execute.
# Success loading search details data about Uncle Waffles
# Function 'get_artist_channel' took 1.1272 seconds to execute.
# Function 'download_batch' took 1.1274 seconds to execute.
# Success loading search details data about NBSPLV
# Function 'get_artist_channel' took 0.9087 seconds to execute.
# Success loading search details data about PNL
# Function 'get_artist_channel' took 0.9942 seconds to execute.
# Success loading search details data about 50 Cent
# Function 'get_artist_channel' took 1.0895 seconds to execute.
# Success loading search details data about Metallica
# Function 'get_artist_channel' took 1.1238 seconds to execute.
# Function 'download_batch' took 1.1245 seconds to execute.
# Success loading search details data about Lvbel C5
# Function 'get_artist_channel' took 1.0520 seconds to execute.
# Success loading search details data about NCT DREAM
# Function 'get_artist_channel' took 1.0593 seconds to execute.
# Success loading search details data about PLK
# Function 'get_artist_channel' took 1.0883 seconds to execute.
# Success loading search details data about De Mthuda
# Function 'get_artist_channel' took 1.0882 seconds to execute.
# Function 'download_batch' took 1.0910 seconds to execute.
# Success loading search details data about Annalisa
# Function 'get_artist_channel' took 1.0356 seconds to execute.
# Success loading search details data about Canserbero
# Function 'get_artist_channel' took 1.0554 seconds to execute.
# Success loading search details data about SCH
# Function 'get_artist_channel' took 1.1610 seconds to execute.
# Success loading search details data about Melike Şahin
# Function 'get_artist_channel' took 1.1922 seconds to execute.
# Function 'download_batch' took 1.1956 seconds to execute.
# Success loading search details data about Luciano
# Function 'get_artist_channel' took 1.0654 seconds to execute.
# Success loading search details data about Taco Hemingway
# Function 'get_artist_channel' took 1.0818 seconds to execute.
# Success loading search details data about SIRA
# Function 'get_artist_channel' took 1.1173 seconds to execute.
# Success loading search details data about Ryan Lewis
# Function 'get_artist_channel' took 1.2547 seconds to execute.
# Function 'download_batch' took 1.2587 seconds to execute.
# Success loading search details data about Yuuri
# Function 'get_artist_channel' took 1.0857 seconds to execute.
# Success loading search details data about Luck Ra
# Function 'get_artist_channel' took 1.1021 seconds to execute.
# Success loading search details data about Stephen Sanchez
# Function 'get_artist_channel' took 1.1959 seconds to execute.
# Success loading search details data about R3HAB
# Function 'get_artist_channel' took 1.3097 seconds to execute.
# Function 'download_batch' took 1.3131 seconds to execute.
# Success loading search details data about JEON SOMI
# Function 'get_artist_channel' took 1.0500 seconds to execute.
# Success loading search details data about Vance Joy
# Function 'get_artist_channel' took 1.0732 seconds to execute.
# Success loading search details data about Pink Floyd
# Function 'get_artist_channel' took 1.0941 seconds to execute.
# Success loading search details data about Da Muziqal Chef
# Function 'get_artist_channel' took 1.0999 seconds to execute.
# Function 'download_batch' took 1.1012 seconds to execute.
# Success loading search details data about Ava Max
# Function 'get_artist_channel' took 1.0186 seconds to execute.
# Success loading search details data about imase
# Function 'get_artist_channel' took 1.1279 seconds to execute.
# Success loading search details data about Tyler, The Creator
# Function 'get_artist_channel' took 1.1468 seconds to execute.
# Success loading search details data about Harmonize
# Function 'get_artist_channel' took 1.1586 seconds to execute.
# Function 'download_batch' took 1.1615 seconds to execute.
# Success loading search details data about Ado
# Function 'get_artist_channel' took 1.0307 seconds to execute.
# Success loading search details data about Birdy
# Function 'get_artist_channel' took 1.0631 seconds to execute.
# Success loading search details data about Elevation Worship
# Function 'get_artist_channel' took 1.1280 seconds to execute.
# Success loading search details data about Tokischa
# Function 'get_artist_channel' took 1.1323 seconds to execute.
# Function 'download_batch' took 1.1325 seconds to execute.
# Success loading search details data about ITZY
# Function 'get_artist_channel' took 0.9618 seconds to execute.
# Success loading search details data about King Promise
# Function 'get_artist_channel' took 1.0118 seconds to execute.
# Success loading search details data about BLANCO
# Function 'get_artist_channel' took 1.1325 seconds to execute.
# Success loading search details data about Fireboy DML
# Function 'get_artist_channel' took 1.2841 seconds to execute.
# Function 'download_batch' took 1.2846 seconds to execute.
# Success loading search details data about Hindia
# Function 'get_artist_channel' took 1.0168 seconds to execute.
# Success loading search details data about Halodayı
# Function 'get_artist_channel' took 1.0275 seconds to execute.
# Success loading search details data about Viktor Sheen
# Function 'get_artist_channel' took 1.1024 seconds to execute.
# Success loading search details data about Jelena Karleuša
# Function 'get_artist_channel' took 1.1973 seconds to execute.
# Function 'download_batch' took 1.1991 seconds to execute.
# Success loading search details data about Niklas Dee
# Function 'get_artist_channel' took 1.0638 seconds to execute.
# Success loading search details data about SB Maffija
# Function 'get_artist_channel' took 1.1170 seconds to execute.
# Success loading search details data about Tzanca Uraganu
# Function 'get_artist_channel' took 1.1292 seconds to execute.
# Success loading search details data about WizKid
# Function 'get_artist_channel' took 1.1386 seconds to execute.
# Function 'download_batch' took 1.1424 seconds to execute.
# Success loading search details data about Ryan Gosling
# Function 'get_artist_channel' took 1.0509 seconds to execute.
# Success loading search details data about Trippie Redd
# Function 'get_artist_channel' took 1.0617 seconds to execute.
# Success loading search details data about Summer Walker
# Function 'get_artist_channel' took 1.1144 seconds to execute.
# Success loading search details data about Dr. Dre
# ...
# Function 'get_artist_channel' took 1.1134 seconds to execute.
# Function 'download_batch' took 1.1169 seconds to execute.
# Success loading search details data about Lloyiso
# Function 'get_artist_channel' took 0.9312 seconds to execute.
# Success loading search details data about KOLA
# Function 'get_artist_channel' took 0.9781 seconds to execute.
# Success loading search details data about Zé Felipe
# Function 'get_artist_channel' took 1.0739 seconds to execute.
# Success loading search details data about Mon Laferte
# Function 'get_artist_channel' took 1.0920 seconds to execute.
# Function 'download_batch' took 1.0933 seconds to execute.
# Success loading search details data about Yaşlı Amca
# Function 'get_artist_channel' took 0.9789 seconds to execute.
# Success loading search details data about Yiyo Sarante
# Function 'get_artist_channel' took 1.0372 seconds to execute.
# Success loading search details data about Liam Gallagher
# Function 'get_artist_channel' took 1.0543 seconds to execute.
# Success loading search details data about Lil Dou
# Function 'get_artist_channel' took 1.0739 seconds to execute.
# Function 'download_batch' took 1.0753 seconds to execute.
# Success loading search details data about Jamie Fine
# Function 'get_artist_channel' took 1.0014 seconds to execute.
# Success loading search details data about Maggie Rogers
# Function 'get_artist_channel' took 1.0654 seconds to execute.
# Success loading search details data about G-Eazy
# Function 'get_artist_channel' took 1.1279 seconds to execute.
# Success loading search details data about Ceasar
# Function 'get_artist_channel' took 1.3996 seconds to execute.
# Function 'download_batch' took 1.4003 seconds to execute.
# Success loading search details data about Szpaku, Kubi Producent
# Function 'get_artist_channel' took 1.0170 seconds to execute.
# Success loading search details data about Remzie Osmani
# Function 'get_artist_channel' took 1.0666 seconds to execute.
# Success loading search details data about IQ
# Function 'get_artist_channel' took 1.0797 seconds to execute.
# Success loading search details data about 6lack
# Function 'get_artist_channel' took 1.1648 seconds to execute.
# Function 'download_batch' took 1.1660 seconds to execute.
# Success loading search details data about A$AP Rocky
# Function 'get_artist_channel' took 1.0285 seconds to execute.
# Success loading search details data about Jaap Reesema
# Function 'get_artist_channel' took 1.0334 seconds to execute.
# Success loading search details data about Gloria Groove
# Function 'get_artist_channel' took 1.0446 seconds to execute.
# Success loading search details data about Paul Kalkbrenner
# Function 'get_artist_channel' took 1.1836 seconds to execute.
# Function 'download_batch' took 1.1862 seconds to execute.
# Success loading search details data about Quest Pistols
# Function 'get_artist_channel' took 0.9857 seconds to execute.
# Success loading search details data about MAX BARSKIH
# Function 'get_artist_channel' took 1.0084 seconds to execute.
# Success loading search details data about Abd El Basset Hamouda
# Function 'get_artist_channel' took 1.0570 seconds to execute.
# Success loading search details data about Schlafmusik
# Function 'get_artist_channel' took 1.0997 seconds to execute.
# Function 'download_batch' took 1.1000 seconds to execute.
# Success loading search details data about Teodora
# Function 'get_artist_channel' took 1.0300 seconds to execute.
# Success loading search details data about Carla's Dreams
# Function 'get_artist_channel' took 1.0527 seconds to execute.
# Success loading search details data about Zoë Tauran
# Function 'get_artist_channel' took 1.0603 seconds to execute.
# Success loading search details data about Fy
# Function 'get_artist_channel' took 1.0614 seconds to execute.
# Function 'download_batch' took 1.0656 seconds to execute.
# Success loading search details data about 草東沒有派對
# Function 'get_artist_channel' took 1.0194 seconds to execute.
# Success loading search details data about R. City
# Function 'get_artist_channel' took 1.0371 seconds to execute.
# Success loading search details data about Ghost
# Function 'get_artist_channel' took 1.0441 seconds to execute.
# Success loading search details data about La petite culotte
# Function 'get_artist_channel' took 1.1598 seconds to execute.
# Function 'download_batch' took 1.1629 seconds to execute.
# Success loading search details data about Niko Pandetta
# Function 'get_artist_channel' took 1.0075 seconds to execute.
# Success loading search details data about Kany Garcia
# Function 'get_artist_channel' took 1.0125 seconds to execute.
# Success loading search details data about Chase Atlantic
# Function 'get_artist_channel' took 1.0308 seconds to execute.
# Success loading search details data about Blæst
# Function 'get_artist_channel' took 1.0482 seconds to execute.
# Function 'download_batch' took 1.0517 seconds to execute.
# Success loading search details data about SunKissed Lola
# Function 'get_artist_channel' took 0.9267 seconds to execute.
# Success loading search details data about EeQue
# Function 'get_artist_channel' took 1.0257 seconds to execute.
# Success loading search details data about Silly Fools
# Function 'get_artist_channel' took 1.0475 seconds to execute.
# Success loading search details data about Khaled
# Function 'get_artist_channel' took 1.0534 seconds to execute.
# Function 'download_batch' took 1.0576 seconds to execute.
# Success loading search details data about Firuz Ruzmetov
# Function 'get_artist_channel' took 0.9726 seconds to execute.
# Success loading search details data about Joaquin Medina
# Function 'get_artist_channel' took 1.0129 seconds to execute.
# Success loading search details data about Latifa
# Function 'get_artist_channel' took 1.0387 seconds to execute.
# Success loading search details data about Jack Black
# Function 'get_artist_channel' took 1.1224 seconds to execute.
# Function 'download_batch' took 1.1245 seconds to execute.
# Success loading search details data about Nas
# Function 'get_artist_channel' took 0.9690 seconds to execute.
# Success loading search details data about Saad El Ghamidi
# Function 'get_artist_channel' took 1.0049 seconds to execute.
# Success loading search details data about Albatraoz
# Function 'get_artist_channel' took 1.0434 seconds to execute.
# Success loading search details data about ooes
# Function 'get_artist_channel' took 1.1353 seconds to execute.
# Function 'download_batch' took 1.1390 seconds to execute.
# Success loading search details data about Beret
# Function 'get_artist_channel' took 0.9967 seconds to execute.
# Success loading search details data about Eliza Rose
# Function 'get_artist_channel' took 1.0298 seconds to execute.
# Success loading search details data about ARMADA 2222 DARIO
# Function 'get_artist_channel' took 1.0785 seconds to execute.
# Success loading search details data about Fairouz
# Function 'get_artist_channel' took 1.1725 seconds to execute.
# Function 'download_batch' took 1.1747 seconds to execute.
# Success loading search details data about Adamlar
# Function 'get_artist_channel' took 1.0163 seconds to execute.
# Success loading search details data about Gilga Sahid
# Function 'get_artist_channel' took 1.0202 seconds to execute.
# Success loading search details data about Edward Maya
# Function 'get_artist_channel' took 1.0935 seconds to execute.
# Success loading search details data about Bloody Hawk
# Function 'get_artist_channel' took 1.2059 seconds to execute.
# Function 'download_batch' took 1.2096 seconds to execute.
# Success loading search details data about Amit Trivedi
# Function 'get_artist_channel' took 0.9596 seconds to execute.
# Success loading search details data about Walk Off the Earth
# Function 'get_artist_channel' took 0.9773 seconds to execute.
# Success loading search details data about Big Zulu
# Function 'get_artist_channel' took 1.0665 seconds to execute.
# Success loading search details data about Montaigne
# Function 'get_artist_channel' took 1.0663 seconds to execute.
# Function 'download_batch' took 1.0700 seconds to execute.
# Success loading search details data about Tom MacDonald
# Function 'get_artist_channel' took 0.9761 seconds to execute.
# Success loading search details data about スピッツ
# Function 'get_artist_channel' took 1.0319 seconds to execute.
# Success loading search details data about Boyd Kosiyabong
# Function 'get_artist_channel' took 1.0825 seconds to execute.
# Success loading search details data about BØRNS
# Function 'get_artist_channel' took 1.1228 seconds to execute.
# Function 'download_batch' took 1.1231 seconds to execute.
# Success loading search details data about Cory Asbury
# Function 'get_artist_channel' took 1.0057 seconds to execute.
# Success loading search details data about Cover By PALM
# Function 'get_artist_channel' took 1.0708 seconds to execute.
# Success loading search details data about Wayne
# Function 'get_artist_channel' took 1.0739 seconds to execute.
# Success loading search details data about LONGMAN
# Function 'get_artist_channel' took 1.2225 seconds to execute.
# Function 'download_batch' took 1.2232 seconds to execute.
# Success loading search details data about Cazzu
# Function 'get_artist_channel' took 1.2047 seconds to execute.
# Success loading search details data about 結束バンド
# Function 'get_artist_channel' took 1.2246 seconds to execute.
# Success loading search details data about Polycat
# Function 'get_artist_channel' took 1.2372 seconds to execute.
# Success loading search details data about Jay Tauleka
# Function 'get_artist_channel' took 1.2545 seconds to execute.
# Function 'download_batch' took 1.2575 seconds to execute.
# Success loading search details data about Josefine Götestam
# Function 'get_artist_channel' took 1.0047 seconds to execute.
# Success loading search details data about チョーキューメイ
# Function 'get_artist_channel' took 1.0778 seconds to execute.
# Success loading search details data about Adam Mišík
# Function 'get_artist_channel' took 1.1074 seconds to execute.
# Success loading search details data about Kubi Producent
# Function 'get_artist_channel' took 1.1329 seconds to execute.
# Function 'download_batch' took 1.1336 seconds to execute.
# Success loading search details data about Senzabenza
# Function 'get_artist_channel' took 0.9754 seconds to execute.
# Success loading search details data about Young Igi
# Function 'get_artist_channel' took 1.0124 seconds to execute.
# Success loading search details data about Santaferia
# Function 'get_artist_channel' took 1.0424 seconds to execute.
# Success loading search details data about Sanja Vucic
# Function 'get_artist_channel' took 1.0621 seconds to execute.
# Function 'download_batch' took 1.0627 seconds to execute.
# Success loading search details data about Harold Faltermeyer
# Function 'get_artist_channel' took 1.0638 seconds to execute.
# Success loading search details data about LH
# Function 'get_artist_channel' took 1.1182 seconds to execute.
# Success loading search details data about Vika Jigulina
# Function 'get_artist_channel' took 1.1635 seconds to execute.
# Success loading search details data about Reality Club
# Function 'get_artist_channel' took 1.1924 seconds to execute.
# Function 'download_batch' took 1.1959 seconds to execute.
# Success loading search details data about Noga Erez
# Function 'get_artist_channel' took 0.9792 seconds to execute.
# Success loading search details data about MYA
# Function 'get_artist_channel' took 1.0972 seconds to execute.
# Success loading search details data about the King will come
# Function 'get_artist_channel' took 1.1419 seconds to execute.
# Success loading search details data about Eypio
# Function 'get_artist_channel' took 1.1668 seconds to execute.
# Function 'download_batch' took 1.1690 seconds to execute.
# Success loading search details data about Mavado
# Function 'get_artist_channel' took 1.0548 seconds to execute.
# Success loading search details data about AnasSAyed
# Function 'get_artist_channel' took 1.0731 seconds to execute.
# Success loading search details data about Bedoes
# Function 'get_artist_channel' took 1.1181 seconds to execute.
# Success loading search details data about Crni Cerak
# Function 'get_artist_channel' took 1.2771 seconds to execute.
# Function 'download_batch' took 1.2796 seconds to execute.
# Success loading search details data about Anyuri
# Function 'get_artist_channel' took 0.9006 seconds to execute.
# Success loading search details data about Abdullah Al Farwan
# Function 'get_artist_channel' took 0.9393 seconds to execute.
# Success loading search details data about Justin Noble Paul
# Function 'get_artist_channel' took 1.0987 seconds to execute.
# Success loading search details data about Juan Luis Guerra 4.40
# Function 'get_artist_channel' took 1.1514 seconds to execute.
# Function 'download_batch' took 1.1516 seconds to execute.
# Success loading search details data about BV2.0
# Function 'get_artist_channel' took 0.9372 seconds to execute.
# Success loading search details data about Favst
# Function 'get_artist_channel' took 1.0090 seconds to execute.
# Success loading search details data about Jonas Blue
# Function 'get_artist_channel' took 1.0685 seconds to execute.
# Success loading search details data about Ruby
# Function 'get_artist_channel' took 1.1366 seconds to execute.
# Function 'download_batch' took 1.1368 seconds to execute.
# Success loading search details data about Daybe
# Function 'get_artist_channel' took 0.9757 seconds to execute.
# Success loading search details data about Abdul Majeed Abdullah
# Function 'get_artist_channel' took 1.0188 seconds to execute.
# Success loading search details data about elijah woods
# Function 'get_artist_channel' took 1.0528 seconds to execute.
# Success loading search details data about Bring Me The Horizon
# Function 'get_artist_channel' took 1.1847 seconds to execute.
# Function 'download_batch' took 1.1892 seconds to execute.
# Success loading search details data about La Cima Cartel
# Function 'get_artist_channel' took 0.9777 seconds to execute.
# Success loading search details data about Damn Yury
# Function 'get_artist_channel' took 1.0586 seconds to execute.
# Success loading search details data about Lykke Li
# Function 'get_artist_channel' took 1.0694 seconds to execute.
# Success loading search details data about Darkhan Juzz
# Function 'get_artist_channel' took 1.1681 seconds to execute.
# Function 'download_batch' took 1.1684 seconds to execute.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 for batch in artist_batch:
# ----> 2     download_batch(batch)
#
# Cell In[2], line 4, in time_logger.<locals>.wrapper(*args, **kwargs)
#       2 def wrapper(*args, **kwargs):
#       3     start_time = time.time()
# ----> 4     result = func(*args, **kwargs)
#       5     end_time = time.time()
#       6     execution_time = end_time - start_time
#
# Cell In[2], line 25, in download_batch(urls)
#      23     thread.start()
#      24 for thread in threads:
# ---> 25     thread.join()
#
# File /usr/local/python/3.10.8/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/local/python/3.10.8/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
# Success loading search details data about Zee_nhle
# Function 'get_artist_channel' took 1.1422 seconds to execute.
# Success loading search details data about Przemek.pro
# Function 'get_artist_channel' took 1.1488 seconds to execute.
# Success loading search details data about Alicia Keys
# Function 'get_artist_channel' took 1.1997 seconds to execute.
# Success loading search details data about JJ Lin
# Function 'get_artist_channel' took 1.4161 seconds to execute.

# %%
import json 
with open('db.json','w') as f:
    json.dump(dat,f,indent=4)

# %%
import json 
with open('db2.json','w') as f:
    json.dump(dat,f,indent=4)

# %%
len(dat)
# Out:
# 2206
